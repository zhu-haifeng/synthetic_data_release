# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.analyse_results import *

# %% [markdown]
# # Linkage

# %%
dirname = '../tests/linkage/'
linkage_gain = load_results_linkage(dirname)

# %%
models = ['SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0','BTCGAN']
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Naive'), hue='PrivacyGain')
# Out:
#     TargetID      TargetModel FeatureSet Run  TPSyn  FPSyn  AccSyn  \
# 30   ID14086           BTCGAN      Naive   0    1.0    0.6     0.7
# 31   ID14086           BTCGAN      Naive   1    0.8    0.0     0.9
# 32   ID14086           BTCGAN      Naive  10    0.8    0.0     0.9
# 33   ID14086           BTCGAN      Naive  11    1.0    0.4     0.8
# 34   ID14086           BTCGAN      Naive  12    0.6    0.0     0.8
# ..       ...              ...        ...  ..    ...    ...     ...
# 970  ID31432  SanitiserNHSk10      Naive   5    0.0    0.0     0.5
# 971  ID31432  SanitiserNHSk10      Naive   6    0.0    0.0     0.5
# 972  ID31432  SanitiserNHSk10      Naive   7    0.0    0.0     0.5
# 973  ID31432  SanitiserNHSk10      Naive   8    1.0    1.0     0.5
# 974  ID31432  SanitiserNHSk10      Naive   9    0.0    0.0     0.5
#
#      AdvantageSyn  AdvantageRaw  PrivacyGain
# 30            0.4             1          0.6
# 31            0.8             1          0.2
# ...

# %%
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Naive'), hue='AccSyn')

# %%
# models = ['SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Correlations'))
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Correlations'),hue = 'AccSyn')
# Out:
#     TargetID      TargetModel    FeatureSet Run  TPSyn  FPSyn  AccSyn  \
# 0    ID14086           BTCGAN  Correlations   0    1.0    0.6     0.7
# 1    ID14086           BTCGAN  Correlations   1    0.6    0.2     0.7
# 2    ID14086           BTCGAN  Correlations  10    0.6    0.8     0.4
# 3    ID14086           BTCGAN  Correlations  11    0.8    0.4     0.7
# 4    ID14086           BTCGAN  Correlations  12    0.4    0.6     0.4
# ..       ...              ...           ...  ..    ...    ...     ...
# 925  ID31432  SanitiserNHSk10  Correlations   5    0.0    0.0     0.5
# 926  ID31432  SanitiserNHSk10  Correlations   6    1.0    1.0     0.5
# 927  ID31432  SanitiserNHSk10  Correlations   7    1.0    1.0     0.5
# 928  ID31432  SanitiserNHSk10  Correlations   8    0.0    0.0     0.5
# 929  ID31432  SanitiserNHSk10  Correlations   9    0.0    0.0     0.5
#
#      AdvantageSyn  AdvantageRaw  PrivacyGain
# 0             0.4             1          0.6
# ...

# %% [markdown]
# # Inference

# %%
dirname = '../tests/inference/'
dpath = '../data/texas'
inference_gain = load_results_inference(dirname, dpath)

# %%
# models = ['SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'))
# Out:
#     Dataset TargetID SensitiveAttribute Run      TargetModel  \
# 60    texas  ID14086               RACE   0           BTCGAN
# 61    texas  ID14086               RACE   0      BayesianNet
# 62    texas  ID14086               RACE   0  PrivBayesEps1.0
# 63    texas  ID14086               RACE   0  SanitiserNHSk10
# 64    texas  ID14086               RACE   1           BTCGAN
# ..      ...      ...                ...  ..              ...
# 595   texas  ID31432               RACE   8  SanitiserNHSk10
# 596   texas  ID31432               RACE   9           BTCGAN
# 597   texas  ID31432               RACE   9      BayesianNet
# 598   texas  ID31432               RACE   9  PrivBayesEps1.0
# 599   texas  ID31432               RACE   9  SanitiserNHSk10
#
#      ProbCorrectRawIn  ProbCorrectRawOut  AdvantageRaw  ProbCorrectSynIn  \
# 60                1.0                1.0           0.0               1.0
# 61                1.0                1.0           0.0               1.0
# ...

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='ProbCorrectRawIn')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='ProbCorrectRawOut')

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='ProbCorrectSynIn')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='ProbCorrectSynOut')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='AdvantageSyn')

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='AdvantageRaw')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'), hue='AdvantageSyn')

# %%
# 连续属性
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'))
# Out:
#     Dataset TargetID SensitiveAttribute Run      TargetModel  \
# 0     texas  ID14086       LengthOfStay   0           BTCGAN
# 1     texas  ID14086       LengthOfStay   0      BayesianNet
# 2     texas  ID14086       LengthOfStay   0  PrivBayesEps1.0
# 3     texas  ID14086       LengthOfStay   0  SanitiserNHSk10
# 4     texas  ID14086       LengthOfStay   1           BTCGAN
# ..      ...      ...                ...  ..              ...
# 535   texas  ID31432       LengthOfStay   8  SanitiserNHSk10
# 536   texas  ID31432       LengthOfStay   9           BTCGAN
# 537   texas  ID31432       LengthOfStay   9      BayesianNet
# 538   texas  ID31432       LengthOfStay   9  PrivBayesEps1.0
# 539   texas  ID31432       LengthOfStay   9  SanitiserNHSk10
#
#      ProbCorrectRawIn  ProbCorrectRawOut  AdvantageRaw  ProbCorrectSynIn  \
# 0                 1.0      8.269030e-263      1.000000      4.651013e-08
# 1                 1.0      8.269030e-263      1.000000      2.100611e-03
# ...

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'), hue='AdvantageRaw')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'), hue='AdvantageSyn')

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'), hue='ProbCorrectRawIn')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'), hue='ProbCorrectRawOut')

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'), hue='ProbCorrectSynOut')
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'), hue='ProbCorrectSynIn')

# %% [markdown]
# # Aggregate Utility

# %%
dirname = '../tests/utility/'
utility_record, utility_agg = load_results_utility(dirname)

# %%
labelVar = 'RiskMortality'
# models = ['Raw','SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_avg_accuracy(utility_agg, models)
