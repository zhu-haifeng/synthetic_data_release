# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from warnings import filterwarnings
filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.analyse_results import *

# %% [markdown]
# # Linkage

# %%
dirname = '../tests/linkage/'
linkage_gain = load_results_linkage(dirname)

# %%
models = ['SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Naive'))
# Out:
#     TargetID      TargetModel FeatureSet Run  TPSyn  FPSyn  AdvantageSyn  \
# 30   ID14086      BayesianNet      Naive   0    1.0    0.6           0.4
# 31   ID14086      BayesianNet      Naive   1    0.4    1.0          -0.6
# 32   ID14086      BayesianNet      Naive  10    0.4    1.0          -0.6
# 33   ID14086      BayesianNet      Naive  11    0.4    1.0          -0.6
# 34   ID14086      BayesianNet      Naive  12    0.6    0.6           0.0
# ..       ...              ...        ...  ..    ...    ...           ...
# 745  ID31432  SanitiserNHSk10      Naive   5    0.0    1.0          -1.0
# 746  ID31432  SanitiserNHSk10      Naive   6    1.0    0.0           1.0
# 747  ID31432  SanitiserNHSk10      Naive   7    0.0    1.0          -1.0
# 748  ID31432  SanitiserNHSk10      Naive   8    0.0    1.0          -1.0
# 749  ID31432  SanitiserNHSk10      Naive   9    1.0    1.0           0.0
#
#      AdvantageRaw  PrivacyGain
# 30              1          0.6
# 31              1          1.6
# 32              1          1.6
# 33              1          1.6
# 34              1          1.0
# ..            ...          ...
# 745             1          2.0
# 746             1          0.0
# 747             1          2.0
# 748             1          2.0
# 749             1          1.0
#
# [225 rows x 9 columns]

# %%
models = ['SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(linkage_gain, models, resFilter=('FeatureSet', 'Correlations'))
# Out:
#     TargetID      TargetModel    FeatureSet Run  TPSyn  FPSyn  AdvantageSyn  \
# 0    ID14086      BayesianNet  Correlations   0    1.0    0.4           0.7
# 1    ID14086      BayesianNet  Correlations   1    0.4    1.0           0.7
# 2    ID14086      BayesianNet  Correlations  10    1.0    0.4           0.7
# 3    ID14086      BayesianNet  Correlations  11    0.6    0.4           0.5
# 4    ID14086      BayesianNet  Correlations  12    0.8    0.8           0.8
# ..       ...              ...           ...  ..    ...    ...           ...
# 700  ID31432  SanitiserNHSk10  Correlations   5    1.0    0.0           0.5
# 701  ID31432  SanitiserNHSk10  Correlations   6    0.0    1.0           0.5
# 702  ID31432  SanitiserNHSk10  Correlations   7    0.0    1.0           0.5
# 703  ID31432  SanitiserNHSk10  Correlations   8    1.0    0.0           0.5
# 704  ID31432  SanitiserNHSk10  Correlations   9    1.0    0.0           0.5
#
#      AdvantageRaw  PrivacyGain
# 0               1          0.3
# 1               1          0.3
# 2               1          0.3
# 3               1          0.5
# 4               1          0.2
# ..            ...          ...
# 700             1          0.5
# 701             1          0.5
# 702             1          0.5
# 703             1          0.5
# 704             1          0.5
#
# [225 rows x 9 columns]

# %% [markdown]
# # Inference

# %%
dirname = '../tests/inference/'
dpath = '../data/texas'
inference_gain = load_results_inference(dirname, dpath)

# %%
models = ['SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'RACE'))

# %%
fig = plt_per_target_pg(inference_gain, models, resFilter=('SensitiveAttribute', 'LengthOfStay'))

# %% [markdown]
# # Aggregate Utility

# %%
dirname = '../tests/utility/'
utility_record, utility_agg = load_results_utility(dirname)

# %%
labelVar = 'RiskMortality'
models = ['Raw','SanitiserNHSk10', 'BayesianNet', 'PrivBayesEps1.0']
fig = plt_avg_accuracy(utility_agg, models)
